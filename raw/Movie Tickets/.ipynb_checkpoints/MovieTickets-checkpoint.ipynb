# %% [markdown]
# # Movie Tickets Visualization

# %% [markdown]
# For the second week, I decided to use data I have personally collected. I'm a big fan of movies and I want to make sense of my data to get insights on my viewing preferences (and slightly curious as well on how much I've spent already on watching movies). My dataset is a bit of small so I teamed up with a friend to analyze our viewing preferences. It is still a bit small and I stopped collecting after August of last year, but for the sake of practice, I'll be proceeding anyway for the analysis.
#
# Disclaimer: I realized that the dataset is really small; thus the results will not generalize my friend and I's viewing preferences. I started collecting since April of 2016 and stopped at August of 2017. There is a possibility that I may have missed possible entries in the dataset (failed to take note or collect movie tickets) so the results does not really conclude anything.

# %% [markdown]
# First, I'll load the necessary files and libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import datetime
import os
import math
import seaborn as sns
import matplotlib.patches as mpatches
from matplotlib.colors import LinearSegmentedColormap, ColorConverter
import re
import matplotlib.dates as dates
# %matplotlib inline

pd.set_option('display.max_columns', None)

# %%
path = os.getcwd() + '/movietickets.csv'
movies = pd.read_csv(path, lineterminator='\n', encoding='latin-1')
movies.shape
# Out:
# (27, 8)

# %%
movies
# Out:
#       User                       Movie                Location        Date  \
# 0    Kharl                The Huntsman  Robinsons Place Manila  16/04/2016
# 1    Kharl  Captain America: Civil War               SM Bacoor  27/04/2016
# 2    Kharl           X-Men: Apocalypse               SM Bacoor  01/06/2016
# 3    Kharl            Now You See Me 2               SM Bacoor  08/06/2016
# 4    Kharl            Now You See Me 2                     ATC  11/06/2016
# 5   Bianca           Star Trek: Beyond           Festival Mall  30/07/2016
# 6    Kharl               Suicide Squad  Robinsons Place Manila  04/08/2016
# 7   Bianca              Doctor Strange           Festival Mall  28/10/2016
# 8   Bianca                       Moana  Robinsons Place Manila  09/12/2016
# 9    Kharl                       Moana  Robinsons Place Manila  09/12/2016
# 10  Bianca                   Rogue One           SM Muntinlupa  16/12/2016
# 11   Kharl                   Seklusyon         SM Mall of Asia  27/12/2016
# 12   Kharl                  Passengers       SM Trece Martires  09/01/2017
# 13   Kharl                  La La Land               SM Bacoor  12/01/2017
# 14  Bianca                  La La Land  Robinsons Place Manila  16/01/2017
# 15   Kharl        The Space Between Us  Robinsons Place Manila  03/02/2017
# 16  Bianca                       Logan        Starmall Alabang  10/03/2017
# 17  Bianca   Guardians of the Galaxy 2        Ayala South Park  30/04/2017
# 18   Kharl              A Silent Voice  Robinsons Place Manila  12/05/2017
# 19   Kharl                Wonder Woman  Robinsons Place Manila  05/06/2017
# 20   Kharl       Everything Everything               SM Bacoor  24/06/2017
# 21  Bianca       Spiderman: Homecoming        Ayala South Park  08/07/2017
# 22  Bianca                     Dunkirk        Starmall Alabang  22/07/2017
# 23   Kharl                   Kita Kita             SM Megamall  22/07/2017
# 24  Bianca    Smurfs: The Lost Village        Ayala South Park  02/04/2017
# 25   Kharl                 Baby Driver  Robinsons Place Manila  02/08/2017
# 26  Bianca                 Baby Driver  Robinsons Place Manila  02/08/2017
#
#         Time  No. of Tickets  Cost  Total
# 0    1:30 PM               1   210    210
# 1    5:50 PM               1   270    270
# 2    5:20 PM               1   210    210
# 3   11:30 AM               1   210    210
# 4    1:15 PM               1   270    270
# 5    9:00 PM               1   200    200
# 6    4:20 PM               1   210    210
# 7    7:15 PM               4   210    840
# 8    2:45 PM               2   200    400
# 9    2:45 PM               2   200    400
# 10   8:00 PM               2   220    440
# 11   1:35 PM               1   281    281
# 12   2:10 PM               1   210    210
# 13   5:00 PM               1   200    200
# 14  11:20 AM               1   210    210
# 15  12:50 PM               1   190    190
# 16  10:20 PM               2   230    460
# 17  10:00 PM               4   181    724
# 18   7:30 PM               1   180    180
# 19   4:10 PM               1   220    220
# 20   3:15 PM               1   200    200
# 21   1:30 PM               2   181    362
# 22   9:20 PM               2   231    462
# 23   2:45 PM               2   245    490
# 24   2:45 PM               1   181    181
# 25   5:00 PM               1   210    210
# 26   5:00 PM               1   210    210

# %% [markdown]
# I've listed a few questions that I want answers from my dataset:
# 1. How many movies have each person watched?
# 2. What is the total cost spent on movie by each person?
# 3. What months do users commonly watch movies in theaters?
# 4. What are the different and similar movies watched by the users?
# 5. What movie theaters are the most common?
# 6. What time frames do users usually watch movies?

# %% [markdown]
# ### 1. How many movies have each person watched?

# %% [markdown]
# The total number of movies watched aggregates the unique occurrence of a movie by a person. This does not sum up the number of tickets bought by the user.
#
# To get the total number of movies, we group the dataset by each person and get the movie count.

# %%
num_movies_watched = movies.groupby('User').agg({'Movie': 'nunique'}).reset_index()
num_movies_watched
# Out:
#      User  Movie
# 0  Bianca     11
# 1   Kharl     15

# %% [markdown]
# I've seen 11 movies in theaters during the timeframe of April 2016 - August 2017 while Kharl has seen 15 movies. This means that on average, Kharl watches a movie on theaters once a month (plus a rest month on this timeframe).

# %% [markdown]
# ### 2. What is the total cost spent on movie by each person?

# %% [markdown]
# Now here's the most important part, how much did we spend on movies during this timeframe? Note that the total cost spent only counts one ticket per purchase. To get this, I simply added the total cost per person.

# %%
total_cost = pd.DataFrame(movies.groupby(['User'])['Cost'].sum()).reset_index()
total_cost
# Out:
#      User  Cost
# 0  Bianca  2254
# 1   Kharl  3516

# %% [markdown]
# If we divide the total cost to the number of movies, I spend P204 for each movie ticket, on average. Kharl, on the other hand, spends P234 for each movie ticket on average. That's a P30 increase in the prices, maybe switch to a new theater instead?

# %% [markdown]
# ### 3. What months do users commonly watch movies in theaters?

# %% [markdown]
# What month do we usually watch movies? I'm guessing it's on May because most blockbuster movies release during the summer, specifically May. But let the data do the talking.
#
# First, let's clean the data and convert the Date column to the %d/%m/%y format using the following code.

# %%
movies['Date'] = pd.to_datetime(movies['Date'], format='%d/%m/%Y')

# %% [markdown]
# Then, we can split the Date column to get the months only.

# %%
movies['Year'] = movies['Date'].dt.year
movies['Month'] = movies['Date'].dt.month
movies
# Out:
#       User                       Movie                Location       Date  \
# 0    Kharl                The Huntsman  Robinsons Place Manila 2016-04-16
# 1    Kharl  Captain America: Civil War               SM Bacoor 2016-04-27
# 2    Kharl           X-Men: Apocalypse               SM Bacoor 2016-06-01
# 3    Kharl            Now You See Me 2               SM Bacoor 2016-06-08
# 4    Kharl            Now You See Me 2                     ATC 2016-06-11
# 5   Bianca           Star Trek: Beyond           Festival Mall 2016-07-30
# 6    Kharl               Suicide Squad  Robinsons Place Manila 2016-08-04
# 7   Bianca              Doctor Strange           Festival Mall 2016-10-28
# 8   Bianca                       Moana  Robinsons Place Manila 2016-12-09
# 9    Kharl                       Moana  Robinsons Place Manila 2016-12-09
# 10  Bianca                   Rogue One           SM Muntinlupa 2016-12-16
# 11   Kharl                   Seklusyon         SM Mall of Asia 2016-12-27
# 12   Kharl                  Passengers       SM Trece Martires 2017-01-09
# 13   Kharl                  La La Land               SM Bacoor 2017-01-12
# 14  Bianca                  La La Land  Robinsons Place Manila 2017-01-16
# 15   Kharl        The Space Between Us  Robinsons Place Manila 2017-02-03
# 16  Bianca                       Logan        Starmall Alabang 2017-03-10
# 17  Bianca   Guardians of the Galaxy 2        Ayala South Park 2017-04-30
# 18   Kharl              A Silent Voice  Robinsons Place Manila 2017-05-12
# 19   Kharl                Wonder Woman  Robinsons Place Manila 2017-06-05
# 20   Kharl       Everything Everything               SM Bacoor 2017-06-24
# 21  Bianca       Spiderman: Homecoming        Ayala South Park 2017-07-08
# 22  Bianca                     Dunkirk        Starmall Alabang 2017-07-22
# 23   Kharl                   Kita Kita             SM Megamall 2017-07-22
# 24  Bianca    Smurfs: The Lost Village        Ayala South Park 2017-04-02
# 25   Kharl                 Baby Driver  Robinsons Place Manila 2017-08-02
# 26  Bianca                 Baby Driver  Robinsons Place Manila 2017-08-02
#
#         Time  No. of Tickets  Cost  Total  Year  Month
# 0    1:30 PM               1   210    210  2016      4
# 1    5:50 PM               1   270    270  2016      4
# 2    5:20 PM               1   210    210  2016      6
# 3   11:30 AM               1   210    210  2016      6
# 4    1:15 PM               1   270    270  2016      6
# 5    9:00 PM               1   200    200  2016      7
# 6    4:20 PM               1   210    210  2016      8
# 7    7:15 PM               4   210    840  2016     10
# 8    2:45 PM               2   200    400  2016     12
# 9    2:45 PM               2   200    400  2016     12
# 10   8:00 PM               2   220    440  2016     12
# 11   1:35 PM               1   281    281  2016     12
# 12   2:10 PM               1   210    210  2017      1
# 13   5:00 PM               1   200    200  2017      1
# 14  11:20 AM               1   210    210  2017      1
# 15  12:50 PM               1   190    190  2017      2
# 16  10:20 PM               2   230    460  2017      3
# 17  10:00 PM               4   181    724  2017      4
# 18   7:30 PM               1   180    180  2017      5
# 19   4:10 PM               1   220    220  2017      6
# 20   3:15 PM               1   200    200  2017      6
# 21   1:30 PM               2   181    362  2017      7
# 22   9:20 PM               2   231    462  2017      7
# 23   2:45 PM               2   245    490  2017      7
# 24   2:45 PM               1   181    181  2017      4
# 25   5:00 PM               1   210    210  2017      8
# 26   5:00 PM               1   210    210  2017      8

# %%
movies_b = movies.loc[movies['User'] == 'Bianca']
frequent_month_count = movies_b['Month'].value_counts().max() 
frequent_month = movies_b['Month'].value_counts().idxmax()

# %% [markdown]
# I was wrong! July was the month where I watched the most movies on theaters. Meanwhile, Kharl usually goes to theaters on August. I can't think of any possible explanation for this except that movies released in the middle of the year are usually blockbusters. Here's a viz comparing the number of movies watched in a certain month between Kharl and I.

# %%
month_bianca = movies.loc[movies['User'] == 'Bianca']['Month']
month_kharl = movies.loc[movies['User'] == 'Kharl']['Month']
months = np.arange(12)
months_label = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']

# %%
b = movies.loc[movies['User'] == 'Bianca']
k = movies.loc[movies['User'] == 'Kharl']
month_bianca_count = []
month_kharl_count = []

for i in range(1, 13):
    month_bianca_count.append(len(b.loc[b['Month'] == i]))
    month_kharl_count.append(len(k.loc[k['Month'] == i]))

# %%
fig, ax = plt.subplots(figsize=(15,7))
width = 0.35
rects1 = ax.bar(months, month_bianca_count, width, color='orange', alpha=0.5)
rects2 = ax.bar(months + width, month_kharl_count, width, color='green', alpha=0.5)

# add some text for labels, title and axes ticks
ax.set_ylabel('Number of movies watched')
ax.set_title('Month')
ax.set_xticks(months)
ax.set_xticklabels(months_label)

ax.legend((rects1[0], rects2[0]), ('Bianca', 'Kharl'))
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,7))

line1 = plt.plot(months, month_bianca_count, marker='o', color='orange', alpha=0.5, linewidth=3, markersize=10)
line2 = plt.plot(months, month_kharl_count, marker='o', color='green', alpha=0.5, linewidth=3, markersize=10)
ax.set_xticks(months)
ax.set_xticklabels(months_label)
ax.legend((line1[0], line2[0]), ('Bianca', 'Kharl'))
plt.ylabel('Number of movies watched')

plt.show()

# %% [markdown]
# ### 4. What are the different and similar movies watched by the users?

# %%
movies
# Out:
#       User                       Movie                Location       Date  \
# 0    Kharl                The Huntsman  Robinsons Place Manila 2016-04-16
# 1    Kharl  Captain America: Civil War               SM Bacoor 2016-04-27
# 2    Kharl           X-Men: Apocalypse               SM Bacoor 2016-06-01
# 3    Kharl            Now You See Me 2               SM Bacoor 2016-06-08
# 4    Kharl            Now You See Me 2                     ATC 2016-06-11
# 5   Bianca           Star Trek: Beyond           Festival Mall 2016-07-30
# 6    Kharl               Suicide Squad  Robinsons Place Manila 2016-08-04
# 7   Bianca              Doctor Strange           Festival Mall 2016-10-28
# 8   Bianca                       Moana  Robinsons Place Manila 2016-12-09
# 9    Kharl                       Moana  Robinsons Place Manila 2016-12-09
# 10  Bianca                   Rogue One           SM Muntinlupa 2016-12-16
# 11   Kharl                   Seklusyon         SM Mall of Asia 2016-12-27
# 12   Kharl                  Passengers       SM Trece Martires 2017-01-09
# 13   Kharl                  La La Land               SM Bacoor 2017-01-12
# 14  Bianca                  La La Land  Robinsons Place Manila 2017-01-16
# 15   Kharl        The Space Between Us  Robinsons Place Manila 2017-02-03
# 16  Bianca                       Logan        Starmall Alabang 2017-03-10
# 17  Bianca   Guardians of the Galaxy 2        Ayala South Park 2017-04-30
# 18   Kharl              A Silent Voice  Robinsons Place Manila 2017-05-12
# 19   Kharl                Wonder Woman  Robinsons Place Manila 2017-06-05
# 20   Kharl       Everything Everything               SM Bacoor 2017-06-24
# 21  Bianca       Spiderman: Homecoming        Ayala South Park 2017-07-08
# 22  Bianca                     Dunkirk        Starmall Alabang 2017-07-22
# 23   Kharl                   Kita Kita             SM Megamall 2017-07-22
# 24  Bianca    Smurfs: The Lost Village        Ayala South Park 2017-04-02
# 25   Kharl                 Baby Driver  Robinsons Place Manila 2017-08-02
# 26  Bianca                 Baby Driver  Robinsons Place Manila 2017-08-02
#
#         Time  No. of Tickets  Cost  Total  Year  Month
# 0    1:30 PM               1   210    210  2016      4
# 1    5:50 PM               1   270    270  2016      4
# 2    5:20 PM               1   210    210  2016      6
# 3   11:30 AM               1   210    210  2016      6
# 4    1:15 PM               1   270    270  2016      6
# 5    9:00 PM               1   200    200  2016      7
# 6    4:20 PM               1   210    210  2016      8
# 7    7:15 PM               4   210    840  2016     10
# 8    2:45 PM               2   200    400  2016     12
# 9    2:45 PM               2   200    400  2016     12
# 10   8:00 PM               2   220    440  2016     12
# 11   1:35 PM               1   281    281  2016     12
# 12   2:10 PM               1   210    210  2017      1
# 13   5:00 PM               1   200    200  2017      1
# 14  11:20 AM               1   210    210  2017      1
# 15  12:50 PM               1   190    190  2017      2
# 16  10:20 PM               2   230    460  2017      3
# 17  10:00 PM               4   181    724  2017      4
# 18   7:30 PM               1   180    180  2017      5
# 19   4:10 PM               1   220    220  2017      6
# 20   3:15 PM               1   200    200  2017      6
# 21   1:30 PM               2   181    362  2017      7
# 22   9:20 PM               2   231    462  2017      7
# 23   2:45 PM               2   245    490  2017      7
# 24   2:45 PM               1   181    181  2017      4
# 25   5:00 PM               1   210    210  2017      8
# 26   5:00 PM               1   210    210  2017      8

# %%
# keep only matching rows
len(movies['Movie'].value_counts())
pd.Series(list(set(b['Movie']) & set(k['Movie'])))
# Out:
# 0     La La Land
# 1          Moana
# 2    Baby Driver
# dtype: object

# %% [markdown]
# Out of 23 total movies we watched in theaters, only 3 movies are common. Out of the 3, we watched 2 movies on the same theater. I initially thought we'd have similar movies seen so to find that only 3 are common was surprising.

# %% [markdown]
# ### 5. What movie theaters are the most common?

# %% [markdown]
# I'm guessing Robinsons Place Manila would be the most common as Manila is the only place that is common to us. But I still want to know how frequent each person visits a certain theater.

# %%
# keep only matching rows
len(movies['Location'].value_counts())
pd.Series(list(set(b['Location']) & set(k['Location'])))
# Out:
# 0    Robinsons Place Manila
# dtype: object

# %% [markdown]
# The above code confirms that Robinsons Place Manila is the most common. 10 movies were seen in this theater, where 2 are common.

# %%
b = movies.loc[movies['User'] == 'Bianca']
k = movies.loc[movies['User'] == 'Kharl']
month_bianca_count = []
month_kharl_count = []

for i in range(1, 13):
    month_bianca_count.append(len(b.loc[b['Month'] == i]))
    month_kharl_count.append(len(k.loc[k['Month'] == i]))

# %%
location_bianca = b['Location'].unique()
location_bianca_count = b['Location'].value_counts()
N = len(location_bianca)

fig, ax = plt.subplots(figsize=(15,7))
width = 0.35
rects1 = ax.bar(np.arange(N), location_bianca_count, width, color='orange', alpha=0.5)

# add some text for labels, title and axes ticks
ax.set_ylabel('Number of movies watched')
ax.set_xlabel('Location')
ax.set_xticks(np.arange(N))
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
ax.set_xticklabels(location_bianca)

plt.show()
